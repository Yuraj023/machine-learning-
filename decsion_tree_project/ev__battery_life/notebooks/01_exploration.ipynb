# %% [markdown]
# in this we will exploraing the ev battery life bataset and checking is this have any noise or not
#
# so in this we will do
# - checking the columns
# - checking the rows
# - checking the missing value and also duplicate values
# - there is any miss datayped

# %% [markdown]
# step 1: fristly we import the required library

# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# step 2: loading the dataset

# %%
df = pd.read_csv(r"D:\machine learning\machine_learning\decsion_tree_project\ev__battery_life\dataset\raw_data\ev_battery_failure_dataset.csv")
df
# Out:
#        vehicle_id vehicle_brand vehicle_model vehicle_type  \
# 0        EV100000        Nissan          Leaf          SUV
# 1        EV100001          Audi        e-tron        Sedan
# 2        EV100002        Toyota          bZ4X          Van
# 3        EV100003    Volkswagen          ID.3    Hatchback
# 4        EV100004         Tesla       Model X    Crossover
# ...           ...           ...           ...          ...
# 199995   EV299995           BYD     Song Plus    Hatchback
# 199996   EV299996         Lucid           Air    Crossover
# 199997   EV299997           BYD     Song Plus          SUV
# 199998   EV299998         Tesla       Model Y    Hatchback
# 199999   EV299999         Tesla       Model 3          SUV
#
#         manufacturing_year battery_manufacturer battery_chemistry  \
# 0                   2019.0                 CATL               LMO
# 1                   2018.0          Samsung SDI               NaN
# ...

# %% [markdown]
# step 3 : stastically summery

# %%
df.describe()
# Out:
#        manufacturing_year  battery_capacity_kwh    odometer_km  \
# count       190171.000000         193097.000000  191334.000000
# mean          2019.501333             76.236405  102822.193327
# std              2.873497             21.302330   87965.819977
# min           2015.000000             25.000000     500.000000
# 25%           2017.000000             60.980000   36128.000000
# 50%           2020.000000             75.350000   78919.000000
# 75%           2022.000000             89.990000  146010.750000
# max           2024.000000            149.010000  450000.000000
#
#        vehicle_age_years    cycle_count  battery_health_percent  \
# count      192317.000000  192348.000000           191018.000000
# mean            6.495245     296.383934               87.381787
# std             2.878180     282.614453               12.540742
# min             1.370000       1.000000               21.420000
# 25%             4.000000      95.000000               80.990000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 70 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   vehicle_id                       200000 non-null  object
#  1   vehicle_brand                    193564 non-null  object
#  2   vehicle_model                    191796 non-null  object
#  3   vehicle_type                     193568 non-null  object
#  4   manufacturing_year               190171 non-null  float64
#  5   battery_manufacturer             193812 non-null  object
#  6   battery_chemistry                192786 non-null  object
#  7   battery_capacity_kwh             193097 non-null  float64
#  8   drive_type                       192732 non-null  object
#  9   odometer_km                      191334 non-null  float64
#  10  vehicle_age_years                192317 non-null  float64
# ...

# %% [markdown]
# step 4: viewing dataset shape

# %%
print(f"Rows : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")
# Out:
# Rows : 200000
# Columns : 70

# %% [markdown]
# step 5: checking duplicate rows

# %%
duplicates = df.duplicated().sum()
print(f"Duplicate Rows : {duplicates}")
# Out:
# Duplicate Rows : 0

# %%
missing_values =( df.isnull().sum().sort_values(ascending= False).to_frame(name = "missing values"))
missing_values["percentage"]=(missing_values["missing values"] / len(df)) * 100
missing_values.head(20)
# Out:
#                              missing values  percentage
# fast_charge_ratio                      9879      4.9395
# average_speed                          9849      4.9245
# manufacturing_year                     9829      4.9145
# home_charging_ratio                    9805      4.9025
# sensor_fault_count                     9674      4.8370
# charging_interruptions                 9648      4.8240
# state_of_charge                        9636      4.8180
# state_of_health                        9565      4.7825
# capacity_loss_percent                  9559      4.7795
# slow_charge_ratio                      9483      4.7415
# cell_temperature_max                   9450      4.7250
# cooling_system_health                  9408      4.7040
# cell_voltage_avg                       9398      4.6990
# charge_efficiency                      9305      4.6525
# hard_braking_score                     9239      4.6195
# average_ambient_temperature            9161      4.5805
# ...

# %% [markdown]
# step 6 : categorical summery

# %%
df.describe(include="object").T
# Out:
#                        count  unique           top    freq
# vehicle_id            200000  200000      EV100000       1
# vehicle_brand         193564      20         Tesla   21840
# vehicle_model         191796      55       Model X    5527
# vehicle_type          193568       6           SUV   58202
# battery_manufacturer  193812       9          CATL   42675
# battery_chemistry     192786       5           NMC  112993
# drive_type            192732       3           FWD   86890
# fleet_or_private      191050       2       Private  137463
# battery_serial        200000  199775  BAT-31225896       2
# terrain_type          192873       5          Flat   67488

# %% [markdown]
# step 7 : datatypes

# %%
df.dtypes.value_counts()
# Out:
# float64    59
# object     10
# int64       1
# Name: count, dtype: int64

# %% [markdown]
# step 8: unique values

# %%
df.nunique().sort_values(ascending=False)
# Out:
# vehicle_id                         200000
# battery_serial                     199775
# odometer_km                        129048
# pack_voltage                        34397
# altitude                            16584
# remaining_capacity                  11952
# cell_voltage_avg                    11584
# battery_capacity_kwh                10957
# average_charge_power_kw             10643
# state_of_charge                      9754
# internal_resistance                  9350
# cell_temperature_max                 8660
# cell_temperature_avg                 7232
# depth_of_discharge                   7186
# state_of_health                      6170
# capacity_loss_percent                6145
# battery_health_percent               6142
# voltage_imbalance                    6046
# average_charging_time                5556
# predicted_remaining_life_cycles      5169
# cell_voltage_std                     4720
# temperature_variance                 2690
# ...

# %% [markdown]
# step 9: targate values

# %%
df["battery_failure"].value_counts(normalize=True)* 100
# Out:
# battery_failure
# 0    90.0395
# 1     9.9605
# Name: proportion, dtype: float64

# %% [markdown]
# step 10: memory usage

# %%
memory = df.memory_usage(deep=True).sum() / (1024**2)

print(f"Dataset Memory : {memory:.2f} MB")
# Out:
# Dataset Memory : 196.22 MB
