# %% [markdown]
# ## Customer Churn Prediction using Logistic Regression
#
# ### Notebook 01 — Data Exploration
#
#
# ### Introduction
#
# Machine Learning projects begin with understanding the dataset before building any predictive model.
#
# In this notebook, we will perform **Data Exploration**, which helps us understand the overall structure of the dataset, identify available features, inspect data types, detect missing values, and examine the target variable.
#
# This exploration provides a solid foundation for data cleaning, feature engineering, and model training in the upcoming notebooks.
#
#
# ### Learning Objectives
#
# By the end of this notebook, we will be able to:
#
# - Load the dataset successfully
# - Understand the business problem
# - Explore the dataset structure
# - Inspect available features
# - Examine data types
# - Identify missing values
# - Detect duplicate records
# - Understand the target variable
# - Prepare the dataset for preprocessing

# %% [markdown]
# ### Step 1 — Import Required Libraries
#
# Before working with the dataset, we first import the necessary Python libraries.
#
# These libraries help us perform data manipulation, numerical computations, and suppress unnecessary warnings to keep the notebook clean and readable.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2 — Load the Dataset
#
# The next step is to load the customer churn dataset into a Pandas DataFrame.
#
# A DataFrame is a two-dimensional data structure that allows us to efficiently store, manipulate, and analyze tabular data.

# %%
df = pd.read_excel(r"D:\machine learning\machine_learning\logistic_regression_project\churn_prediction\data\raw _data\Telco_customer_churn.xlsx")

# %% [markdown]
# ### Step 3 — Preview the Dataset
#
# After loading the dataset, it is always recommended to inspect the first few records.
#
# This helps us verify that the dataset has been loaded correctly and provides an initial understanding of the available features and their values.

# %%
df.head(10)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
# 5  4190-MFLUW      1  United States  California  Los Angeles     90020
# 6  8779-QRDMV      1  United States  California  Los Angeles     90022
# 7  1066-JKSGK      1  United States  California  Los Angeles     90024
# 8  6467-CHFZW      1  United States  California  Los Angeles     90028
# 9  8665-UTDHZ      1  United States  California  Los Angeles     90029
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# ...

# %% [markdown]
# ### Step 4 — Display the Last Five Records
#
# Viewing the last few rows helps ensure that the dataset has been loaded completely and allows us to inspect how the data ends.
#
# Sometimes, missing values or unexpected entries appear toward the end of a dataset, making this step useful for validation.

# %%
df.tail(5)
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female  ...
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male  ...
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female  ...
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female  ...
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male  ...
#
#             Contract Paperless Billing             Payment Method  \
# ...

# %% [markdown]
# ### Step 5 — Check Dataset Dimensions
#
# Understanding the size of the dataset is an important part of data exploration.
#
# The `shape` attribute returns:
#
# - Number of rows (customer records)
# - Number of columns (features)
#
# This information helps estimate the amount of available data for training and analysis.

# %%
df.shape
# Out:
# (7043, 33)

# %%
features_of_dataset = df.shape[1] - 1 
print(f"Number of features in the dataset: {features_of_dataset}")
# Out:
# Number of features in the dataset: 32

# %% [markdown]
# ### Observation
#
# The dataset dimensions tell us:
#
# - in the data set i can see like there was 7043 rows and 33 column.
# - there was 32 features in the this dataset.
# - i can cleary see there was more then 7k rows and for the linear and logistic need to 1k to proper training so it means this was enough - for now

# %% [markdown]
# ### Step 6 — Explore Feature Names
#
# Before preprocessing the dataset, it is important to understand all available columns.
#
# Displaying the feature names helps us identify:
#
# - Customer identifiers
# - Demographic information
# - Service-related features
# - Billing information
# - Contract details
# - Target variable
# - Potentially unnecessary columns

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %% [markdown]
# ### Observation
#
# there was some columns that can be impact on the model after training like noise and can be problem of overfiting
# the columns such as customner_id  count  lat  long churn label
